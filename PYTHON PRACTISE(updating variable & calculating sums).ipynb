# %%
# Que.1 = Create a variable age with value 25 and print it.
age=25 #int
print("Age=",age)
# Out:
# Age= 25

# %%
# que.2 = Create a list of 5 colors and print the third color.
colors=["Red","Blue","Pink","Green","Yellow"] #list of str
print(colors[2])
# Out:
# Pink

# %%
# Que.3 = Update a variable name = "Rahul" to "Amit" and print both old and new values.
name="Rahul" #str
old_name=name
new_name="Amit" #str
print("Old name=",old_name)
print("New name=",new_name)
# Out:
# Old name= Rahul
# New name= Amit

# %%
#Que.4 = Create a list of 5 numbers and calculate the sum.
numbers=[5,6,9,5,4] #list of int
x=sum(numbers)
print(x)
# Out:
# 29

# %%
# Que.5 = Add "Apple" to a list fruits = ["Mango","Banana"].
fruits=["Mango","Banana"] #list of str
fruits.append("Apple")
print(fruits)
# Out:
# ['Mango', 'Banana', 'Apple']

# %%
# Que.6 = Remove "Banana" from a list.
fruits=["Mango","Banana","Apple"] #list of str
fruits.remove("Banana")
print(fruits)
# Out:
# ['Mango', 'Apple']

# %%
# Que.7 = Create a list of marks [50,60,70,80] and update the first element to 55.
marks=[50,60,70,80] #list of int
marks[0]=55
print(marks)
# Out:
# [55, 60, 70, 80]

# %%
# Que.8 = Create a list of 5 cities and print the length of the list.
cities=["Lucknow","Amethi","Jagdishpur","Jais","Gauriganj"] #list of str
x=len
# Out:
# range(0, 9)
