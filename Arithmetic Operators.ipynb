# %% [markdown]
# ## Arithmetic Operators

# %%
#Que.1 Write a Python program to add two numbers 45 and 67 and print the result.
x = 45 #int
y = 67 #int
print(x+y)
# Out:
# 112

# %%
#Que.2 Subtract 35 from 100 and display the answer.
x = 100 #int
y = 35 #int
print(x-y)
# Out:
# 65

# %%
#Que.3 Multiply 23 by 12 and print the result.
x = 23 #int
y = 12 #int
print(x*y)
# Out:
# 276

# %%
#Que.4 Divide 144 by 12 and print the result as a float.
x = 144 #int
y = 23 #int
print(x/y)
# Out:
# 6.260869565217392

# %%
#Que.5 Use floor division to divide 29 by 5 and print the integer result.
x = 29 #int
y = 5 #int
print(x//y)
# Out:
# 5

# %%
#Que.6 Find the remainder when 75 is divided by 8.
x = 75 #int
y = 8 #int
print(x%y)
# Out:
# 3

# %%
#Que.7 Write a program to calculate 5 raised to the power of 4.
x = 5**4 #int
print(x)
# Out:
# 625

# %%
#Que.8 If x = 25 and y = 7, calculate and print the results of all arithmetic operations (+, -, *, /, //, %, **).
x = 25 #int
y = 7 #int
print(x+y)
# Out:
# 32

# %%
x = 25 #int
y = 7 #int
print(x-y)
# Out:
# 18

# %%
x = 25 #int
y = 7 #int
print(x*y)
# Out:
# 175

# %%
x = 25 #int
y = 7 #int
print(x/y)
# Out:
# 3.5714285714285716

# %%
x = 25 #int
y = 7 #int
print(x//y)
# Out:
# 3

# %%
x = 25 #int
y = 7 #int
print(x%y)
# Out:
# 4

# %%
x = 25 #int
y = 7 #int
print(x**y)
# Out:
# 6103515625

# %%
#Que.9 Take two numbers as input from the user and display their sum, difference, product, and division.
num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))
sum_result = num1 + num2
diff_result = num1 - num2
prod_result = num1 * num2
div_result = num1 / num2 if num2 != 0 else "Error: Division by zero"
print("Results:")
print(f"Sum: {num1} + {num2} = {sum_result}")
print(f"Difference: {num1} - {num2} = {diff_result}")
print(f"Product: {num1} * {num2} = {prod_result}")
print(f"Division: {num1} / {num2} = {div_result}")
# Out:
# Enter first number: 10
# Enter second number: 5
# Results:
# Sum: 10.0 + 5.0 = 15.0
# Difference: 10.0 - 5.0 = 5.0
# Product: 10.0 * 5.0 = 50.0
# Division: 10.0 / 5.0 = 2.0

# %%
#Que.10 Write a program to calculate the average of 5 numbers entered by the user using arithmetic operators.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
num4 = float(input("Enter fourth number: "))
num5 = float(input("Enter fifth number: "))

# Calculate sum using arithmetic operator (+)
sum_of_numbers = num1 + num2 + num3 + num4 + num5

# Calculate average
average = sum_of_numbers / 5

# Display average
print(f"Average of 5 numbers: {average}")
# Out:
# Enter first number:  8
# Enter second number:  5
# Enter third number:  6
# Enter fourth number:  3
# Enter fifth number:  5
# Average of 5 numbers: 5.4
